# %% [markdown]
# Load all of the SQL data from csv files and combine into one useful dataframe (and export into new csv if necessary)

# %%
import pandas as pd
import numpy as np
import pypdb as pdb
import os

# %%
def get_path(filename):
    return os.path.join(os.path.dirname(os.getcwd()),
                        'pdb-search',
                        'data',
                        'sql_export',
                        filename)

# %%
types = pd.read_csv(get_path('type.csv'), sep=';')
classes = pd.read_csv(get_path('class.csv'), sep=';')
superfamilies = pd.read_csv(get_path('superfamily.csv'), sep=';')
families = pd.read_csv(get_path('family.csv'), sep=';')
species = pd.read_csv(get_path('species.csv'), sep=';')
membranes = pd.read_csv(get_path('membrane.csv'), sep=';')
proteins = pd.read_csv(get_path('protein.csv'), sep=';')

classifications = pd.read_csv(get_path('classification.csv'), sep=';')

#combined = proteins[]

# %%
classes.head()
#superfamilies.sort_values('number').head()
# Out:
#    id number                             name  description
# 0   1   1.1.          Alpha-helical polytopic          NaN
# 1   2   1.3.        Beta-barrel transmembrane          NaN
# 2   6   2.2.    All beta monotopic/peripheral          NaN
# 3   5   2.1.   All alpha monotopic/peripheral          NaN
# 4   7   2.3.  Alpha/Beta monotopic/peripheral          NaN

# %%
# each row in families['number'] contains a string of numbers separated by periods
# however, there is an extra '.' at the end, which confuses str.split('.')
# so first we must delete the last character by slicing: str[:-1]
# then we split the string in each row into four separate columns, corresponding to:
# type.class.superfamily.family (ex: '1.4.28.03')
# we use these to construct a new dataframe, and finally append the id numbers also
# this allows us to determine the type, class, and superfamily of any protein
# from its family number.

#family_ids = pd.DataFrame([ x[:-1].split('.') for x in families['number'] ],
#                           columns=['type','class','superfamily','family'])
#family_ids = pd.concat([families['id'],family_ids],axis=1)

#family_ids.head()

#class_ids = pd.DataFrame([ x[:4] for x in families['number'] ],
#                           columns=['type','class','superfamily','family'])

families['class_number']=families.number.str[:4]
#families.head()

# %%
families.sort_values('number').head()
# Out:
#       id      number                                             name    tcdb  \
# 12    14  1.1.01.01.                   Microbial and algal rhodopsins   3.E.1
# 13    15  1.1.01.02.            G-protein coupled receptors, family A  9.A.14
# 241  265  1.1.01.03.                         GPCR Secretin (B) family  9.A.14
# 665  734  1.1.01.04.                       Frizzled/Smoothened family  9.A.14
# 689  758  1.1.01.05.  GPCR Metabotropic glutamate receptor (C) family  9.A.14
#
#         pfam
# 12   PF01036
# 13   PF00001
# 241  PF00002
# 665  PF01534
# 689  PF00003

# %%
#first we make a dictionary to translate:
# family id --> family name
# family id --> family number
# class number --> class name
family_names = dict(families[['id','name']].values)
family_class = dict(families[['id','class_number']].values)
class_map = dict(classes[['number','name']].values)

#proteins['class_number']
#x[:4] for x in families['number'] 
proteins['family_name'] = proteins.family_id.replace(family_names)
proteins['class_name'] = proteins.family_id.replace(family_class).replace(class_map)

#alternately, use this to accomplish the same thing in one line:
#proteins['family_name'] = proteins.family_id.replace(families.set_index('id')['name'])
#proteins['class_name'] = proteins.family_id.replace(families.set_index('id')['class_number'])
proteins.head()
# Out:
#      id  family_id  species_id  membrane_id pdbid  \
# 0     1         35           9            3  1qjp
# 1     2        390           9            3  1qj8
# 2     3        363          24            3  1p4t
# 3  1006        286          52           15  3lbw
# 4  1007         37         310            3  2x55
#
#                                                 name resolution topology  \
# 0  Outer membrane protein A (OMPA), disordered loops       1.65     A in
# 1                    Outer membrane protein X (OMPX)       1.90     A in
# 2                        Outer membrane protein NspA       2.55     A in
# 3     M2 proton channel of Influenza A, closed state       1.65    A out
# 4  Plasminogen activator PLA (coagulase/fibrinoly...       1.85     A in
#
#    thickness  thicknesserror            ...              tilterror  gibbs  \
# 0       25.4             1.5            ...                      1  -29.5
# 1       23.6             2.8            ...                      5  -30.7
# 2       24.9             2.4            ...                      3  -42.9
# 3       31.1             1.7            ...                     10  -50.5
# 4       25.6             1.9            ...                      5  -43.9
#
#     tau numsubunits  numstrands  \
# 0  N.D.           1           8
# 1  N.D.           1           8
# 2    28           1           8
# 3   NaN           4           4
# 4   NaN           1          10
#
#                                         verification  \
# 0  Four interfacial Trp residues of OmpA are loca...
# 1  Locations of the hydrophobic boundaries are co...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                             comments  date_added  \
# 0  OmpA is required for the action of colicins K ...  2005-09-04
# 1     OmpX from Escherichia coli promotes adhesio...  2005-09-04
# 2  Pathogenic Neisseria spp. possess a repertoire...  2005-09-04
# 3                                                NaN  0000-00-00
# 4                                                NaN  0000-00-00
#
#                         family_name                 class_name
# 0                       OmpA family  Beta-barrel transmembrane
# 1   Enterobacterial Ail/Lom protein  Beta-barrel transmembrane
# 2                    Opacity porins  Beta-barrel transmembrane
# 3  Influenza virus matrix protein 2           Bitopic proteins
# 4          OM protease omptin, OMPT  Beta-barrel transmembrane
#
# [5 rows x 21 columns]

# %%
proteins.head()
# Out:
#      id  family_id  species_id  membrane_id pdbid  \
# 0     1         35           9            3  1qjp
# 1     2        390           9            3  1qj8
# 2     3        363          24            3  1p4t
# 3  1006        286          52           15  3lbw
# 4  1007         37         310            3  2x55
#
#                                                 name resolution topology  \
# 0  Outer membrane protein A (OMPA), disordered loops       1.65     A in
# 1                    Outer membrane protein X (OMPX)       1.90     A in
# 2                        Outer membrane protein NspA       2.55     A in
# 3     M2 proton channel of Influenza A, closed state       1.65    A out
# 4  Plasminogen activator PLA (coagulase/fibrinoly...       1.85     A in
#
#    thickness  thicknesserror  tilt  tilterror  gibbs   tau  numsubunits  \
# 0       25.4             1.5    11          1  -29.5  N.D.            1
# 1       23.6             2.8    12          5  -30.7  N.D.            1
# 2       24.9             2.4    22          3  -42.9    28            1
# 3       31.1             1.7     7         10  -50.5   NaN            4
# 4       25.6             1.9     4          5  -43.9   NaN            1
#
#    numstrands                                       verification  \
# 0           8  Four interfacial Trp residues of OmpA are loca...
# 1           8  Locations of the hydrophobic boundaries are co...
# 2           8                                                NaN
# 3           4                                                NaN
# 4          10                                                NaN
#
#                                             comments  date_added  \
# 0  OmpA is required for the action of colicins K ...  2005-09-04
# 1     OmpX from Escherichia coli promotes adhesio...  2005-09-04
# 2  Pathogenic Neisseria spp. possess a repertoire...  2005-09-04
# 3                                                NaN  0000-00-00
# 4                                                NaN  0000-00-00
#
#                         family_name
# 0                       OmpA family
# 1   Enterobacterial Ail/Lom protein
# 2                    Opacity porins
# 3  Influenza virus matrix protein 2
# 4          OM protease omptin, OMPT

# %%
classifications
# Out:
#       id  type_id  class_id  superfamily_id  family_id
# 0      1        1         1               2          1
# 1      2        1         1               2          2
# 2      3        1         1               2          3
# 3      4        1         1               2          4
# 4      5        1         1               2          5
# 5      6        1         1             345          6
# 6      7        1         1               3          7
# 7      8        1         1               3          8
# 8      9        1         1               3          9
# 9     10        1         1               3         10
# 10    82        3        11             309         83
# 11    12        1         1               4         12
# 12    13        1         1               5         13
# 13    14        1         1               6         14
# 14    15        1         1               6         15
# 15    16        1         1               7         16
# 16    17        1         1               8         17
# 17    84        1         1               8         85
# 18    19        1         1              10         19
# 19    20        1         1              11         20
# 20    21        1         1              12         21
# 21    22        1         1              13         22
# 22    23        1         1              14         23
# 23    24        1         1              15         24
# 24    25        1         1              16         25
# 25    26        1         1              17         26
# 26   374        1        16             256        366
# 27    28        1         1              19         28
# 28    29        1         1              20         29
# 29    30        1         1              21         30
# ..   ...      ...       ...             ...        ...
# 799  889        1         1             544        877
# 800  890        1         1             346        878
# 801  891        1         1             273        879
# 802  892        2         5              84        880
# 803  893        1        16             488        881
# 804  894        1         2             545        882
# 805  895        2         5             546        883
# 806  896        1         1             547        884
# 807  897        1         2              35        885
# 808  898        1        16             548        886
# 809  899        1         1               4        887
# 810  900        1         1               8        888
# 811  902        1         1              17        890
# 812  903        3        11             154        891
# 813  904        1         1             550        892
# 814  905        2         7             134        893
# 815  906        2         6             120        894
# 816  907        1         1              16        895
# 817  910        1         1               8        898
# 818  911        1         1             552        899
# 819  912        1         1               8        900
# 820  913        3        11             258        901
# 821  914        1        16              74        902
# 822  915        1        16             103        903
# 823  916        1         1               8        904
# 824  917        1         1             553        905
# 825  918        3        14             172        906
# 826  919        2         7             554        907
# 827  920        1         1             555        908
# 828  921        1        16             117        909
#
# [829 rows x 5 columns]
